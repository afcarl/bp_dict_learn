# %%
import librosa
import audio_dl as adl
import scikits.audiolab as audiolab

x, sr = librosa.load('demo.mp3', sr=44100)
X = abs(librosa.stft(x, n_fft=512))
audl = adl.Audio_DL()

# %%
# No pre-processing
figure(1)
audl.process(x, sr)
xl = audl.separate(10)
figure(2)
audl.figures(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-b58c98519dd8> in <module>()
#       1 # No pre-processing
#       2 figure(1)
# ----> 3 audl.process(x, sr)
#       4 xl = audl.separate(10)
#       5 figure(2)
#
# /Users/daliang/Documents/bptdl/audio_dl.py in process(self, x, sr, n_fft, load_mat, filename, log, norm_option, iter, K, dl, visualize)
#      11
#      12     def process(self, x, sr, n_fft=512, load_mat=False, filename='', log=False, norm_option='', iter=200, K=1024, dl=bts.BPTDL_Sampler(), visualize=True):
# ---> 13         self.Xc = librosa.stft(x, sr=sr, n_fft=n_fft)
#      14         X = np.abs(self.Xc)
#      15         ## Configure
#
# TypeError: stft() got an unexpected keyword argument 'sr'

# %%
# Subtract mean
figure(1)
audl.process(x, sr, norm_option='MeanSub')
figure(2)
audl.figures(top=10)
xl = audl.separate(10)
# Out:
# Init the sampler with option: SVD...

# %%
# Standarize
figure(1)
audl.process(x, sr, norm_option='Standarize')
figure(2)
audl.figures(top=10)
xl = audl.separate(10)
# Out:
# Init the sampler with option: SVD...

# %%
# Play the resynthesized top L components
d = sio.loadmat('xl_spec_standarize.mat')
xl = d['xl']
L = xl.shape[0]
for i in xrange(L):
    audiolab.play(xl[i,:])

# %%
# Subtract mean on log-spectra
figure(1)
audl.process(x, sr, log=True, norm_option='MeanSub')
xl = audl.separate(15)
figure(2)
audl.figures(top=15)

# %%
# Standarize on log-spectra
figure(1)
audl.process(x, sr, log=True, norm_option='Standarize')
xl = audl.separate(15)
figure(2)
audl.figures(top=15)
# Out:
# Init the sampler with option: SVD...

# %%
# Try MFCC
import bptdl_sampler as bptdl
MX = librosa.melspectrogram(x, sr=44100)
mdl = bptdl.BPTDL_Sampler()
mdl.sample(MX, 200, K=1024)

# %%
sidx = flipud(argsort(mdl.pi))
plot(mdl.pi[sidx], '-o')

# %%
subplot(211)
imshow(MX, cmap=cm.hot_r, origin='lower', aspect='auto', interpolation='nearest')
colorbar()
subplot(223)
imshow(mdl.D[:,sidx[:50]], cmap=cm.hot_r, origin='lower', aspect='auto', interpolation='nearest')
colorbar()
subplot(224)
imshow(mdl.S[sidx[:50],:]*mdl.Z[sidx[:50],:], cmap=cm.hot_r, origin='lower', aspect='auto', interpolation='nearest')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x12c2fe710>

# %%
MX = (MX - np.mean(MX))/np.sqrt(np.var(MX))
mdl.sample(MX, 100, K=1024)
# Out:
# Init the sampler with option: SVD...

# %%
subplot(211)
imshow(MX, cmap=cm.hot_r, origin='lower', aspect='auto', interpolation='nearest')
colorbar()
subplot(223)
imshow(mdl.D[:,sidx[:50]], cmap=cm.hot_r, origin='lower', aspect='auto', interpolation='nearest')
colorbar()
subplot(224)
imshow(mdl.S[sidx[:50],:]*mdl.Z[sidx[:50],:], cmap=cm.hot_r, origin='lower', aspect='auto', interpolation='nearest')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11220c9e0>
