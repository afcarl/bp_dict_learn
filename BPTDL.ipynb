# %%
import bptdl_sampler as bs
import librosa
x, sr = librosa.load('data/mix_var5a_8k.wav')
X = abs(librosa.stft(x, n_fft=512, sample_rate=sr))

# %%
dl = bs.BPTDL_Sampler(X)
dl.sample(100, K=512)
# Out:
# Init the sampler with option: SVD...
# bptdl_sampler.py:96: RuntimeWarning: overflow encountered in exp
#   tmp = np.exp(tmp) * self.pi[k]

# %%
plot(dl.ll)
